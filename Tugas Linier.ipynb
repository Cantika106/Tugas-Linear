# %%
import pandas as pd

pizza = {'diameter': [2, 4, 8, 12, 16],
         'harga': [3, 5, 9, 13.5, 18]}

pizza_df  = pd.DataFrame(pizza)
pizza_df
# Out:
#    diameter  harga
# 0         2    3.0
# 1         4    5.0
# 2         8    9.0
# 3        12   13.5
# 4        16   18.0

# %%
import matplotlib.pyplot as plt

pizza_df.plot(kind='scatter', x='diameter', y='harga')

plt.title('Perbandingan Diameter dan Harga Pizza')
plt.xlabel('Diameter (inch)')
plt.ylabel('Harga (dollar)')
plt.xlim(0, 25)
plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %%
import numpy as np 

X = np.array(pizza_df['diameter'])
y = np.array(pizza_df['harga'])

print(f'x: {X}')
print(f'y: {y}')
# Out:
# x: [ 2  4  8 12 16]
# y: [ 3.   5.   9.  13.5 18. ]

# %%
X = X.reshape(-1, 1)
X.shape
# Out:
# (5, 1)

# %%
X
# Out:
# array([[ 2],
#        [ 4],
#        [ 8],
#        [12],
#        [16]], dtype=int64)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Define and train the model
X_train = np.array([[0], [25], [50], [75], [100]]).reshape(-1, 1)
y_train = np.array([0, 50, 100, 150, 200])
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
x_vis = np.array([0, 25]).reshape(-1, 1)
y_vis = model.predict(x_vis)

print(y_vis)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 2
#       1 import numpy as np
# ----> 2 from sklearn.linear_model import LinearRegression
#       4 # Define and train the model
#       5 X_train = np.array([[0], [25], [50], [75], [100]]).reshape(-1, 1)
#
# File /lib/python3.11/site-packages/sklearn/__init__.py:83
#      69     # We are not importing the rest of scikit-learn during the build
#      70     # process, as it may not be compiled yet
#      71 else:
#    (...)
#      77     # later is linked to the OpenMP runtime to make it possible to introspect
#      78     # it and importing it first would fail if the OpenMP dll cannot be found.
#      79     from . import (
#      80         __check_build,  # noqa: F401
#      81         _distributor_init,  # noqa: F401
#      82     )
# ---> 83     from .base import clone
#      84     from .utils._show_versions import show_versions
#      86     __all__ = [
#      87         "calibration",
#      88         "cluster",
#    (...)
#     129         "show_versions",
#     130     ]
#
# File /lib/python3.11/site-packages/sklearn/base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import estimator_html_repr
#      21 from .utils._metadata_requests import _MetadataRequester
#
# File /lib/python3.11/site-packages/sklearn/utils/__init__.py:15
#      12 from itertools import compress, islice
#      14 import numpy as np
# ---> 15 from scipy.sparse import issparse
#      17 from .. import get_config
#      18 from ..exceptions import DataConversionWarning
#
# ModuleNotFoundError: The module 'scipy' is included in the Pyodide distribution, but it is not installed.
# You can install it by calling:
#   await micropip.install("scipy") in Python, or
#   await pyodide.loadPackage("scipy") in JavaScript
# See https://pyodide.org/en/stable/usage/loading-packages.html for more details.

# %%
x_vis = np.array([0, 25]).reshape(-1, 1)
y_vis = modal.predict(x_vis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 x_vis = np.array([0, 25]).reshape(-1, 1)
# ----> 2 y_vis = modal.predict(x_vis)
#
# NameError: name 'modal' is not defined

# %%
plt.scatter(X, y)
plt.plot(X_vis, y_vis, '-r')

plt.title('Perbandingan Diameter dan Harga Pizza')
plt.xlabel('Diameter (inch)')
plt.ylabel('Harga (dollar)')
plt.xlim(0, 25)
plt.ylim(0, 25)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 plt.scatter(X, y)
# ----> 2 plt.plot(X_vis, y_vis, '-r')
#       4 plt.title('Perbandingan Diameter dan Harga Pizza')
#       5 plt.xlabel('Diameter (inch)')
#
# NameError: name 'y_vis' is not defined
